# %%
from time import time

import torch
import sklearn.datasets
import sklearn.preprocessing
import sklearn.model_selection
import numpy as np

import onlinehd

# %%
# loads simple mnist dataset
def load():
    # fetches data
    x, y = sklearn.datasets.fetch_openml('mnist_784', return_X_y=True)
    x = x.astype(np.float)
    y = y.astype(np.int)
    y = np.array(y)

    # split and normalize
    x, x_test, y, y_test = sklearn.model_selection.train_test_split(x, y)
    scaler = sklearn.preprocessing.Normalizer().fit(x)
    x = scaler.transform(x)
    x_test = scaler.transform(x_test)

    # changes data to pytorch's tensors
    x = torch.from_numpy(x).float()
    y = torch.from_numpy(y).long()
    x_test = torch.from_numpy(x_test).float()
    y_test = torch.from_numpy(y_test).long()

    return x, x_test, y, y_test

# %%
# simple OnlineHD training

print('Loading...')
x, x_test, y, y_test = load()
classes = y.unique().size(0)
# Out:
# Loading...

# %%
features = x.size(1)
model = onlinehd.OnlineHD(classes, features)

if torch.cuda.is_available():
    x = x.cuda()
    y = y.cuda()
    x_test = x_test.cuda()
    y_test = y_test.cuda()
    model = model.to('cuda')
    print('Using GPU!')

print('Training...')
t = time()
model = model.fit(x, y, bootstrap=1.0, lr=0.035, epochs=20)
t = time() - t

print('Validating...')
yhat = model(x)
yhat_test = model(x_test)
acc = (y == yhat).float().mean()
acc_test = (y_test == yhat_test).float().mean()
print(f'{acc = :6f}')
print(f'{acc_test = :6f}')
print(f'{t = :6f}')
# Out:
# Training...
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7134, 0.6019, 0.6992,  ..., 0.6469, 0.6867, 0.6719],
#         [0.7823, 0.6098, 0.6916,  ..., 0.6865, 0.6746, 0.6765],
#         [0.6390, 0.6498, 0.7641,  ..., 0.6536, 0.6884, 0.6511],
#         ...,
#         [0.6525, 0.5961, 0.6524,  ..., 0.6522, 0.6439, 0.6454],
#         [0.6862, 0.5853, 0.6499,  ..., 0.6368, 0.6276, 0.6361],
#         [0.6506, 0.6075, 0.6540,  ..., 0.6332, 0.6918, 0.6606]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2013],
#         [0.2177],
#         [0.2359],
#         ...,
#         [0.3478],
#         [0.3138],
#         [0.2823]]) torch.Size([1024, 1])
# tensor([[-0.2013],
#         [-0.2177],
#         [-0.2359],
#         ...,
#         [-0.3267],
#         [-0.3138],
#         [-0.2823]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7150, 0.6032, 0.7000,  ..., 0.6487, 0.6889, 0.6731],
#         [0.7815, 0.6109, 0.6907,  ..., 0.6876, 0.6761, 0.6794],
#         [0.6399, 0.6510, 0.7643,  ..., 0.6550, 0.6886, 0.6525],
#         ...,
#         [0.6535, 0.5969, 0.6518,  ..., 0.6532, 0.6449, 0.6481],
#         [0.6859, 0.5865, 0.6492,  ..., 0.6381, 0.6291, 0.6378],
#         [0.6519, 0.6087, 0.6545,  ..., 0.6350, 0.6927, 0.6612]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2033],
#         [0.2185],
#         [0.2357],
#         ...,
#         [0.3468],
#         [0.3141],
#         [0.2822]]) torch.Size([1024, 1])
# tensor([[-0.2033],
#         [-0.2185],
#         [-0.2357],
#         ...,
#         [-0.3281],
#         [-0.3141],
#         [-0.2822]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7163, 0.6043, 0.7007,  ..., 0.6501, 0.6907, 0.6740],
#         [0.7807, 0.6119, 0.6899,  ..., 0.6884, 0.6775, 0.6815],
#         [0.6408, 0.6520, 0.7642,  ..., 0.6561, 0.6888, 0.6537],
#         ...,
#         [0.6544, 0.5975, 0.6515,  ..., 0.6540, 0.6457, 0.6502],
#         [0.6856, 0.5874, 0.6486,  ..., 0.6391, 0.6303, 0.6391],
#         [0.6529, 0.6096, 0.6550,  ..., 0.6365, 0.6932, 0.6617]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2051],
#         [0.2193],
#         [0.2358],
#         ...,
#         [0.3460],
#         [0.3144],
#         [0.2822]]) torch.Size([1024, 1])
# tensor([[-0.2051],
#         [-0.2193],
#         [-0.2358],
#         ...,
#         [-0.3291],
#         [-0.3144],
#         [-0.2822]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7175, 0.6052, 0.7013,  ..., 0.6514, 0.6921, 0.6747],
#         [0.7799, 0.6126, 0.6895,  ..., 0.6891, 0.6786, 0.6832],
#         [0.6415, 0.6527, 0.7638,  ..., 0.6571, 0.6889, 0.6546],
#         ...,
#         [0.6550, 0.5980, 0.6513,  ..., 0.6547, 0.6465, 0.6518],
#         [0.6853, 0.5881, 0.6483,  ..., 0.6400, 0.6313, 0.6400],
#         [0.6538, 0.6104, 0.6556,  ..., 0.6378, 0.6936, 0.6621]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2066],
#         [0.2201],
#         [0.2362],
#         ...,
#         [0.3453],
#         [0.3147],
#         [0.2823]]) torch.Size([1024, 1])
# tensor([[-0.2066],
#         [-0.2201],
#         [-0.2362],
#         ...,
#         [-0.3301],
#         [-0.3147],
#         [-0.2823]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7185, 0.6060, 0.7019,  ..., 0.6525, 0.6933, 0.6753],
#         [0.7791, 0.6133, 0.6893,  ..., 0.6896, 0.6797, 0.6845],
#         [0.6421, 0.6533, 0.7633,  ..., 0.6580, 0.6889, 0.6554],
#         ...,
#         [0.6556, 0.5984, 0.6513,  ..., 0.6553, 0.6473, 0.6531],
#         [0.6850, 0.5888, 0.6482,  ..., 0.6407, 0.6322, 0.6407],
#         [0.6546, 0.6111, 0.6562,  ..., 0.6390, 0.6938, 0.6626]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2079],
#         [0.2209],
#         [0.2367],
#         ...,
#         [0.3447],
#         [0.3150],
#         [0.2824]]) torch.Size([1024, 1])
# tensor([[-0.2079],
#         [-0.2209],
#         [-0.2367],
#         ...,
#         [-0.3308],
#         [-0.3150],
#         [-0.2824]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7195, 0.6068, 0.7025,  ..., 0.6534, 0.6943, 0.6758],
#         [0.7784, 0.6139, 0.6893,  ..., 0.6901, 0.6807, 0.6857],
#         [0.6426, 0.6539, 0.7626,  ..., 0.6587, 0.6890, 0.6562],
#         ...,
#         [0.6561, 0.5988, 0.6514,  ..., 0.6559, 0.6480, 0.6541],
#         [0.6847, 0.5894, 0.6481,  ..., 0.6413, 0.6330, 0.6413],
#         [0.6554, 0.6117, 0.6568,  ..., 0.6400, 0.6940, 0.6630]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2091],
#         [0.2216],
#         [0.2374],
#         ...,
#         [0.3441],
#         [0.3153],
#         [0.2827]]) torch.Size([1024, 1])
# tensor([[-0.2091],
#         [-0.2216],
#         [-0.2374],
#         ...,
#         [-0.3315],
#         [-0.3153],
#         [-0.2827]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7203, 0.6075, 0.7031,  ..., 0.6543, 0.6952, 0.6763],
#         [0.7776, 0.6144, 0.6893,  ..., 0.6904, 0.6815, 0.6866],
#         [0.6431, 0.6543, 0.7619,  ..., 0.6593, 0.6890, 0.6569],
#         ...,
#         [0.6565, 0.5991, 0.6515,  ..., 0.6563, 0.6487, 0.6550],
#         [0.6844, 0.5899, 0.6482,  ..., 0.6418, 0.6337, 0.6419],
#         [0.6560, 0.6122, 0.6575,  ..., 0.6409, 0.6940, 0.6634]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2101],
#         [0.2224],
#         [0.2381],
#         ...,
#         [0.3437],
#         [0.3156],
#         [0.2829]]) torch.Size([1024, 1])
# tensor([[-0.2101],
#         [-0.2224],
#         [-0.2381],
#         ...,
#         [-0.3320],
#         [-0.3156],
#         [-0.2829]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7210, 0.6081, 0.7036,  ..., 0.6550, 0.6958, 0.6768],
#         [0.7769, 0.6148, 0.6894,  ..., 0.6907, 0.6823, 0.6875],
#         [0.6436, 0.6547, 0.7611,  ..., 0.6600, 0.6891, 0.6575],
#         ...,
#         [0.6568, 0.5993, 0.6518,  ..., 0.6568, 0.6493, 0.6556],
#         [0.6841, 0.5903, 0.6483,  ..., 0.6423, 0.6344, 0.6424],
#         [0.6566, 0.6127, 0.6581,  ..., 0.6417, 0.6940, 0.6639]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2111],
#         [0.2231],
#         [0.2389],
#         ...,
#         [0.3432],
#         [0.3159],
#         [0.2832]]) torch.Size([1024, 1])
# tensor([[-0.2111],
#         [-0.2231],
#         [-0.2389],
#         ...,
#         [-0.3324],
#         [-0.3159],
#         [-0.2832]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7217, 0.6087, 0.7041,  ..., 0.6557, 0.6964, 0.6772],
#         [0.7762, 0.6152, 0.6896,  ..., 0.6910, 0.6830, 0.6882],
#         [0.6440, 0.6551, 0.7603,  ..., 0.6605, 0.6892, 0.6581],
#         ...,
#         [0.6571, 0.5995, 0.6520,  ..., 0.6572, 0.6498, 0.6562],
#         [0.6838, 0.5907, 0.6485,  ..., 0.6427, 0.6350, 0.6428],
#         [0.6572, 0.6131, 0.6587,  ..., 0.6425, 0.6940, 0.6643]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2120],
#         [0.2238],
#         [0.2397],
#         ...,
#         [0.3428],
#         [0.3162],
#         [0.2835]]) torch.Size([1024, 1])
# tensor([[-0.2120],
#         [-0.2238],
#         [-0.2397],
#         ...,
#         [-0.3328],
#         [-0.3162],
#         [-0.2835]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7222, 0.6093, 0.7045,  ..., 0.6564, 0.6969, 0.6777],
#         [0.7755, 0.6156, 0.6898,  ..., 0.6912, 0.6837, 0.6888],
#         [0.6443, 0.6554, 0.7595,  ..., 0.6610, 0.6893, 0.6587],
#         ...,
#         [0.6574, 0.5997, 0.6523,  ..., 0.6576, 0.6503, 0.6567],
#         [0.6834, 0.5911, 0.6487,  ..., 0.6430, 0.6355, 0.6432],
#         [0.6576, 0.6136, 0.6594,  ..., 0.6432, 0.6939, 0.6647]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2128],
#         [0.2245],
#         [0.2405],
#         ...,
#         [0.3424],
#         [0.3166],
#         [0.2838]]) torch.Size([1024, 1])
# tensor([[-0.2128],
#         [-0.2245],
#         [-0.2405],
#         ...,
#         [-0.3331],
#         [-0.3166],
#         [-0.2838]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7227, 0.6098, 0.7050,  ..., 0.6569, 0.6972, 0.6781],
#         [0.7748, 0.6159, 0.6900,  ..., 0.6914, 0.6843, 0.6894],
#         [0.6447, 0.6558, 0.7587,  ..., 0.6616, 0.6894, 0.6592],
#         ...,
#         [0.6576, 0.5999, 0.6526,  ..., 0.6580, 0.6508, 0.6572],
#         [0.6831, 0.5915, 0.6489,  ..., 0.6433, 0.6360, 0.6436],
#         [0.6581, 0.6139, 0.6599,  ..., 0.6439, 0.6938, 0.6652]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2136],
#         [0.2252],
#         [0.2413],
#         ...,
#         [0.3420],
#         [0.3169],
#         [0.2841]]) torch.Size([1024, 1])
# tensor([[-0.2136],
#         [-0.2252],
#         [-0.2413],
#         ...,
#         [-0.3334],
#         [-0.3169],
#         [-0.2841]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7232, 0.6104, 0.7054,  ..., 0.6575, 0.6976, 0.6785],
#         [0.7742, 0.6163, 0.6903,  ..., 0.6915, 0.6849, 0.6900],
#         [0.6450, 0.6561, 0.7579,  ..., 0.6620, 0.6895, 0.6597],
#         ...,
#         [0.6578, 0.6001, 0.6529,  ..., 0.6584, 0.6513, 0.6576],
#         [0.6828, 0.5918, 0.6491,  ..., 0.6436, 0.6365, 0.6439],
#         [0.6585, 0.6143, 0.6604,  ..., 0.6445, 0.6936, 0.6656]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2143],
#         [0.2258],
#         [0.2421],
#         ...,
#         [0.3416],
#         [0.3172],
#         [0.2844]]) torch.Size([1024, 1])
# tensor([[-0.2143],
#         [-0.2258],
#         [-0.2421],
#         ...,
#         [-0.3337],
#         [-0.3172],
#         [-0.2844]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7235, 0.6109, 0.7058,  ..., 0.6580, 0.6979, 0.6789],
#         [0.7735, 0.6166, 0.6905,  ..., 0.6916, 0.6854, 0.6906],
#         [0.6453, 0.6564, 0.7571,  ..., 0.6625, 0.6897, 0.6602],
#         ...,
#         [0.6579, 0.6002, 0.6532,  ..., 0.6587, 0.6517, 0.6580],
#         [0.6825, 0.5922, 0.6493,  ..., 0.6438, 0.6370, 0.6443],
#         [0.6588, 0.6147, 0.6609,  ..., 0.6451, 0.6935, 0.6660]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2150],
#         [0.2265],
#         [0.2429],
#         ...,
#         [0.3413],
#         [0.3175],
#         [0.2848]]) torch.Size([1024, 1])
# tensor([[-0.2150],
#         [-0.2265],
#         [-0.2429],
#         ...,
#         [-0.3339],
#         [-0.3175],
#         [-0.2848]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7239, 0.6115, 0.7062,  ..., 0.6584, 0.6982, 0.6793],
#         [0.7729, 0.6170, 0.6908,  ..., 0.6917, 0.6859, 0.6911],
#         [0.6456, 0.6568, 0.7563,  ..., 0.6629, 0.6898, 0.6606],
#         ...,
#         [0.6581, 0.6004, 0.6535,  ..., 0.6590, 0.6521, 0.6583],
#         [0.6823, 0.5925, 0.6495,  ..., 0.6440, 0.6374, 0.6446],
#         [0.6592, 0.6151, 0.6614,  ..., 0.6456, 0.6934, 0.6663]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2157],
#         [0.2271],
#         [0.2437],
#         ...,
#         [0.3410],
#         [0.3177],
#         [0.2851]]) torch.Size([1024, 1])
# tensor([[-0.2157],
#         [-0.2271],
#         [-0.2437],
#         ...,
#         [-0.3342],
#         [-0.3177],
#         [-0.2851]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7241, 0.6120, 0.7065,  ..., 0.6589, 0.6984, 0.6797],
#         [0.7724, 0.6173, 0.6911,  ..., 0.6917, 0.6864, 0.6915],
#         [0.6459, 0.6571, 0.7555,  ..., 0.6633, 0.6900, 0.6610],
#         ...,
#         [0.6583, 0.6006, 0.6538,  ..., 0.6593, 0.6525, 0.6586],
#         [0.6820, 0.5929, 0.6498,  ..., 0.6442, 0.6378, 0.6449],
#         [0.6594, 0.6154, 0.6618,  ..., 0.6461, 0.6932, 0.6667]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2164],
#         [0.2276],
#         [0.2445],
#         ...,
#         [0.3407],
#         [0.3180],
#         [0.2854]]) torch.Size([1024, 1])
# tensor([[-0.2164],
#         [-0.2276],
#         [-0.2445],
#         ...,
#         [-0.3344],
#         [-0.3180],
#         [-0.2854]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7244, 0.6125, 0.7068,  ..., 0.6593, 0.6987, 0.6800],
#         [0.7718, 0.6177, 0.6914,  ..., 0.6917, 0.6868, 0.6920],
#         [0.6461, 0.6574, 0.7547,  ..., 0.6636, 0.6902, 0.6614],
#         ...,
#         [0.6585, 0.6008, 0.6541,  ..., 0.6596, 0.6529, 0.6589],
#         [0.6817, 0.5932, 0.6501,  ..., 0.6443, 0.6381, 0.6451],
#         [0.6597, 0.6158, 0.6622,  ..., 0.6466, 0.6931, 0.6670]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2170],
#         [0.2282],
#         [0.2453],
#         ...,
#         [0.3404],
#         [0.3183],
#         [0.2857]]) torch.Size([1024, 1])
# tensor([[-0.2170],
#         [-0.2282],
#         [-0.2453],
#         ...,
#         [-0.3345],
#         [-0.3183],
#         [-0.2857]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7246, 0.6130, 0.7071,  ..., 0.6596, 0.6989, 0.6804],
#         [0.7712, 0.6180, 0.6917,  ..., 0.6918, 0.6872, 0.6924],
#         [0.6463, 0.6577, 0.7540,  ..., 0.6640, 0.6903, 0.6618],
#         ...,
#         [0.6586, 0.6009, 0.6544,  ..., 0.6599, 0.6532, 0.6591],
#         [0.6815, 0.5935, 0.6503,  ..., 0.6445, 0.6385, 0.6454],
#         [0.6600, 0.6161, 0.6626,  ..., 0.6470, 0.6930, 0.6673]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2176],
#         [0.2288],
#         [0.2460],
#         ...,
#         [0.3401],
#         [0.3185],
#         [0.2860]]) torch.Size([1024, 1])
# tensor([[-0.2176],
#         [-0.2288],
#         [-0.2460],
#         ...,
#         [-0.3347],
#         [-0.3185],
#         [-0.2860]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7248, 0.6136, 0.7074,  ..., 0.6600, 0.6991, 0.6807],
#         [0.7706, 0.6183, 0.6919,  ..., 0.6918, 0.6876, 0.6927],
#         [0.6466, 0.6581, 0.7532,  ..., 0.6642, 0.6905, 0.6622],
#         ...,
#         [0.6587, 0.6011, 0.6547,  ..., 0.6602, 0.6536, 0.6593],
#         [0.6812, 0.5938, 0.6505,  ..., 0.6446, 0.6388, 0.6456],
#         [0.6602, 0.6165, 0.6630,  ..., 0.6475, 0.6929, 0.6677]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2182],
#         [0.2294],
#         [0.2468],
#         ...,
#         [0.3398],
#         [0.3188],
#         [0.2863]]) torch.Size([1024, 1])
# tensor([[-0.2182],
#         [-0.2294],
#         [-0.2468],
#         ...,
#         [-0.3348],
#         [-0.3188],
#         [-0.2863]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7250, 0.6141, 0.7076,  ..., 0.6603, 0.6993, 0.6811],
#         [0.7701, 0.6187, 0.6922,  ..., 0.6918, 0.6879, 0.6930],
#         [0.6468, 0.6584, 0.7525,  ..., 0.6645, 0.6907, 0.6625],
#         ...,
#         [0.6588, 0.6013, 0.6549,  ..., 0.6604, 0.6539, 0.6595],
#         [0.6809, 0.5941, 0.6508,  ..., 0.6447, 0.6391, 0.6458],
#         [0.6604, 0.6168, 0.6633,  ..., 0.6479, 0.6927, 0.6680]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2188],
#         [0.2299],
#         [0.2475],
#         ...,
#         [0.3396],
#         [0.3191],
#         [0.2866]]) torch.Size([1024, 1])
# tensor([[-0.2188],
#         [-0.2299],
#         [-0.2475],
#         ...,
#         [-0.3350],
#         [-0.3191],
#         [-0.2866]]) torch.Size([1024, 1])
# arange: tensor([   0,    1,    2,  ..., 1021, 1022, 1023]) torch.Size([1024])
# scores: tensor([[0.7252, 0.6146, 0.7078,  ..., 0.6607, 0.6994, 0.6814],
#         [0.7695, 0.6190, 0.6925,  ..., 0.6918, 0.6883, 0.6933],
#         [0.6470, 0.6587, 0.7518,  ..., 0.6648, 0.6908, 0.6629],
#         ...,
#         [0.6589, 0.6014, 0.6552,  ..., 0.6607, 0.6542, 0.6597],
#         [0.6806, 0.5944, 0.6510,  ..., 0.6448, 0.6394, 0.6460],
#         [0.6607, 0.6172, 0.6636,  ..., 0.6483, 0.6925, 0.6684]]) torch.Size([1024, 10])
# y: tensor([6, 0, 2,  ..., 7, 0, 5]) torch.Size([1024])
# 10
# ====
# tensor([[0.2194],
#         [0.2305],
#         [0.2482],
#         ...,
#         [0.3393],
#         [0.3194],
#         [0.2869]]) torch.Size([1024, 1])
# tensor([[-0.2194],
#         [-0.2305],
#         [-0.2482],
#         ...,
#         [-0.3351],
#         [-0.3194],
#         [-0.2869]]) torch.Size([1024, 1])
# Validating...
# acc = 0.940933
# acc_test = 0.931657
# t = 10.871503

# %%
features = x.size(1)
model = onlinehd.OnlineHD(classes, features)

if torch.cuda.is_available():
    x = x.cuda()
    y = y.cuda()
    x_test = x_test.cuda()
    y_test = y_test.cuda()
    model = model.to('cuda')
    print('Using GPU!')

print('Training...')
t = time()
model = model.fit(x, y, bootstrap=1.0, lr=0.035, epochs=20)
t = time() - t

print('Validating...')
yhat = model(x)
yhat_test = model(x_test)
acc = (y == yhat).float().mean()
acc_test = (y_test == yhat_test).float().mean()
print(f'{acc = :6f}')
print(f'{acc_test = :6f}')
print(f'{t = :6f}')
# Out:
# Training...
# Validating...
# acc = 0.943124
# acc_test = 0.930686
# t = 10.378816
